# %% [markdown]
# <a href="https://colab.research.google.com/github/jk95-1453/Escape-From-Lusby-Commons-Part-One-Playlist/blob/main/Escape_From_Lusby_Commons%2C_Part_One_Playlist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
escape_from_lusby_commons_part_one_playlist = ["Breaking Point", "I Have No Enemies", "Khaybar", "Leap of Faith", "The Green Pill", "Transformation Complete", "Deal with the Devil"]

# %%
print(escape_from_lusby_commons_part_one_playlist)
# Out:
# ['Breaking Point', 'I Have No Enemies', 'Khaybar', 'Leap of Faith', 'The Green Pill', 'Transformation Complete', 'Deal with the Devil']

# %%
track_length = ["3:25", "3:01", "2:21", "2:09", "4:30", "2:56", "2:26"]

# %%
print(track_length)
# Out:
# ['3:25', '3:01', '2:21', '2:09', '4:30', '2:56', '2:26']

# %%
number_of_tracks = [7]

# %%
print(number_of_tracks)
# Out:
# [7]

# %%
a = [3.25, 3.01, 2.21, 2.09, 4.30, 2.56, 2.26]

# %%
avg = sum(a)/len(a)

# %%
print(avg)
# Out:
# 2.8114285714285714
